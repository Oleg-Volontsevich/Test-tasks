# %% [markdown]
# |  |  |
# | ---: | :--- |
# | Выполнил:| Волонцевич Олег |
# | Дата: | 29.08.2022 |
#
#
# # Парсинг диалогов из файла .csv
#
# Задачи:
#
# * a. Извлекать реплики с приветствием - где менеджер поздоровался.
# * b. Извлекать реплики, где менеджер представил себя.
# * c. Извлекать имя менеджера.
# * d. Извлекать название компании.
# * e. Извлекать реплики, где менеджер попрощался.
# * f. Проверять требование к менеджеру: "в каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом"

# %%
#pip install yargy

# %%
import pandas as pd

import nltk
import pymorphy2

from yargy import Parser, rule
from yargy.predicates import gram, dictionary

# %%
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('test_data.csv')
data
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 3         0       3  manager
# 4         0       4   client
# ..      ...     ...      ...
# 475       5     138  manager
# 476       5     139  manager
# 477       5     140   client
# 478       5     141   client
# 479       5     142  manager
#
#                                                                                                                                  text
# 0                                                                                                                                Алло
# 1                                                                                                                   Алло здравствуйте
# 2                                                                                                                         Добрый день
# 3    Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# 4                                                                                                                                 Ага
# ..                                                                                                                                ...
# 475                                                                         По поводу виджетов и с ними уже обсудите конкретно продам
# 476                                              Все я вам высылаю счет и с вами на связи если будут вопросы можете писать на ватсапе
# 477                                                                                                                   Спасибо спасибо
# 478                                                                                    Да да тогда созвонимся ага спасибо вам давайте
# 479                                                                                                    Ну до свидания хорошего вечера
#
# [480 rows x 4 columns]

# %% [markdown]
# Файл содержит преобразованные в текст телефонные звонки. Отсутствуют знаки препинания, не всегда есть разбивка на предложения, отсутствует верхний регистр кроме первого символа строки (в т.ч. в именах).

# %% [markdown]
# ### Приветствие
# * a. Извлекать реплики с приветствием - где менеджер поздоровался.

# %%
def greeting(row):       
    '''
    функция возвращает True если менеджер поздоровался
    '''
    _txt = row['text'].lower()
    
    if row['role'] != 'manager':
        return False
    else:
        for _gree in greeting_dict:
            if _gree in _txt:
                return True
                break
        return False

# %% [markdown]
# При необходимости можно дополнительно использовать условие для поиска приветствия только в N первых строчках диалога:
#
# * if row['line_n'] >=N:
#     *     return False

# %%
greeting_dict = ['добрый день', 'доброе утро', 'добрый вечер', 'здравствуйте', 'приветствую', 'привет']#словарь приветствий
data['greeting'] = data.apply(greeting, axis=1)
data.head(5)
# Out:
#    dlg_id  line_n     role  \
# 0       0       0   client
# 1       0       1  manager
# 2       0       2   client
# 3       0       3  manager
# 4       0       4   client
#
#                                                                                                                                text  \
# 0                                                                                                                              Алло
# 1                                                                                                                 Алло здравствуйте
# 2                                                                                                                       Добрый день
# 3  Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# 4                                                                                                                               Ага
#
#    greeting
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False

# %% [markdown]
# ### Представился
# * b. Извлекать реплики, где менеджер представил себя.

# %%
def introduce(row):       
    '''
    функция возвращает True если менеджер представился 
    (если в пяти первых строчках диалога использованы обороты из introduce_dict)
    '''
    _txt = row['text'].lower()
    
    if row['line_n'] >5:
        return False 
    elif row['role'] != 'manager':
        return False
    else:
        for _intr in introduce_dict:
            if _intr in _txt:
                return True
                break
        return False

# %%
introduce_dict = ['зовут', 'представиться', 'беспокоит', 'это', 'мое имя']           
data['introduce'] = data.apply(introduce, axis=1)
data[data['dlg_id']==3].head(5)
# Out:
#      dlg_id  line_n     role  \
# 249       3       0   client
# 250       3       1  manager
# 251       3       2  manager
# 252       3       3   client
# 253       3       4  manager
#
#                                                                                                                                                                                                                                                          text  \
# 249                                                                                                                                                                                                                                               Добрый день
# 250                                                                                                                                                                                                                                  Алло дмитрий добрый день
# 251                                                                                                                                                                                              Добрый меня максим зовут компания китобизнес удобно говорить
# 252                                                                                                                                                                                                                                                 Да удобно
# 253  Да дмитрий вот мне моя коллега анастасия подсказала что у вас есть какие то открытые вопросы связанные с техническими особенностями а мы серым вот готов буду его ответить или взять паузу и решите эти вопросы уточните пожалуйста в чем задача состоит
#
#      greeting  introduce
# 249     False      False
# 250      True      False
# 251     False       True
# 252     False      False
# 253     False      False

# %% [markdown]
# ### ФИО
# * c. Извлекать имя менеджера.

# %%
def manager_name(row):       
    '''
    функция ищет ФИО среди первых пяти строчек диалога в репликах где менеджер представился
    Если есть Name-сущности - возвращает собранную из них строку иначе None
    '''
    _txt = row['text']
    _name = None
    if row['line_n'] >5:
        return None 
    elif row['role'] != 'manager':
        return None
    elif row['introduce'] != True:
        return None
    else:
        for word in nltk.word_tokenize(_txt):
            for p in morph.parse(word):
                if 'Name' in p.tag and p.score >= prob_thresh:
                    _name = '' if _name == None else _name
                    _name += word
                    _name += ' '
        _name = None if _name == None else _name.title().rstrip()
        return _name

# %%
prob_thresh = 0.4
morph = pymorphy2.MorphAnalyzer()
data['manager'] = data.apply(manager_name, axis=1)
data[data['manager']==data['manager']]
# Out:
#      dlg_id  line_n     role  \
# 3         0       3  manager
# 111       1       2  manager
# 167       2       3  manager
# 251       3       2  manager
# 338       5       1  manager
#
#                                                                                                                                     text  \
# 3       Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# 111  Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления а мы сели обратила внимание что у вас срок заканчивается
# 167    Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления лицензии а мастера мы с вами сотрудничали по видео там
# 251                                                                         Добрый меня максим зовут компания китобизнес удобно говорить
# 338                                                                                                                     Да это анастасия
#
#      greeting  introduce    manager
# 3       False       True   Ангелина
# 111     False       True   Ангелина
# 167     False       True   Ангелина
# 251     False       True     Максим
# 338     False       True  Анастасия

# %% [markdown]
# ### Компания
# * d. Извлекать название компании.

# %%
def company_name(row):       
    '''
    функция ищет названия компаний согласно заданному правилу для Yargy-парсера
    '''
    _txt = row['text'].lower()
    _company_name = ''
    for match in parser.findall(_txt):
        for x in match.tokens:
            _company_name += x.value
            _company_name += ' '
        return _company_name.rstrip()

# %%
company_rule = rule (dictionary({'компания', 'фирма', 'ооо', 'зао', 'оао', 'ао', 'пао', 'нко', 'оп', 'группа компаний',
                                 'торговый дом', 'ип'}),
                     gram('ADVB').optional(), gram('ADJF').optional(), gram('NOUN').optional(), 
                     dictionary({'и', 'энд'}).optional(), gram('NOUN'))

parser = Parser(company_rule)
data['company'] = data.apply(company_name, axis=1)

# %% [markdown]
# Правило позволяет находить сложные и "заковыристые" названия.
# Тестировалась на списке:
# * компания китобизнес
# * фирма диджитал бизнес
# * группа компаний крутой замес
# * компания рога и копыта
# * ооо вкусно и точка
# * торговый дом матвеев и сыновья
# * ип николаев игорь юрьевич

# %%
data[data['company']==data['company']]
# Out:
#      dlg_id  line_n     role  \
# 3         0       3  manager
# 28        0      28   client
# 50        0      50   client
# 111       1       2  manager
# 167       2       3  manager
# 251       3       2  manager
#
#                                                                                                                                     text  \
# 3       Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# 28                                                                                                    А вот компания в которой я работаю
# 50                                                                                                            Это хорошая компания и 110
# 111  Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления а мы сели обратила внимание что у вас срок заканчивается
# 167    Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления лицензии а мастера мы с вами сотрудничали по видео там
# 251                                                                         Добрый меня максим зовут компания китобизнес удобно говорить
#
#      greeting  introduce   manager                   company
# 3       False       True  Ангелина  компания диджитал бизнес
# 28      False      False      None                компания в
# 50      False      False      None                компания и
# 111     False       True  Ангелина  компания диджитал бизнес
# 167     False       True  Ангелина  компания диджитал бизнес
# 251     False       True    Максим       компания китобизнес

# %% [markdown]
# Есть 2 ложных срабатывания правила (строки 28 и 50). Можно исключить костылем (например по количеству символов) или усложнением логики правила.

# %% [markdown]
# ### Прощание
# * e. Извлекать реплики, где менеджер попрощался.

# %%
def goodbye(row):       
    '''
    функция возвращает True если менеджер попрощался
    '''
    _txt = row['text'].lower()
    
    if row['role'] != 'manager':
        return False
    else:
        for _bye in goodbye_dict:
            if _bye in _txt:
                return True
                break
        return False

# %% [markdown]
# Так же как и с приветствием при необходимости можно искать прощание только в последних строчках диалога.

# %%
goodbye_dict = ['до свидания', 'до связи', 'до звонка', 'до встречи', 'до скорого', 'пока', 'счастливо', 
                'всего хорошего', 'всего вам хорошего', 'всего доброго', 'всего вам доброго', 
                'удачного дня', 'удачного вам дня', 'хорошего дня', 'успехов']
data['goodbye'] = data.apply(goodbye, axis=1)
data[data['dlg_id']==3].tail(5)
# Out:
#      dlg_id  line_n     role  \
# 297       3      48   client
# 298       3      49  manager
# 299       3      50   client
# 300       3      51  manager
# 301       3      52   client
#
#                                                    text  greeting  introduce  \
# 297                         Давайте часов в 11 наверное     False      False
# 298                 11 да смогу набрать в 11 наберу вас     False      False
# 299                                      Угу все хорошо     False      False
# 300  Угу все хорошо да понедельника тогда всего доброго     False      False
# 301                                      Да до свидания     False      False
#
#     manager company  goodbye
# 297    None    None    False
# 298    None    None    False
# 299    None    None    False
# 300    None    None     True
# 301    None    None    False

# %% [markdown]
# ### Приветствие + прощание
# * f. Проверять требование к менеджеру: "в каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом"

# %%
hello_goodbye = data.pivot_table(index=data['dlg_id'], aggfunc={'greeting': (sum), 'goodbye': (sum)})
hello_goodbye['hello_goodbye'] = (hello_goodbye['greeting'] * hello_goodbye['goodbye']) > 0
hello_goodbye
# Out:
#         goodbye  greeting  hello_goodbye
# dlg_id
# 0             1         1           True
# 1             2         1           True
# 2             0         1          False
# 3             1         1           True
# 4             1         0          False
# 5             1         0          False

# %% [markdown]
# Для наглядности добавим менеджера диалога.

# %%
dlg_manager = data[data['manager']==data['manager']]
dlg_manager.set_index('dlg_id', inplace=True)
hello_goodbye = pd.merge(hello_goodbye, dlg_manager['manager'], how="left", on="dlg_id")
hello_goodbye.style.highlight_null(null_color='yellow')
# Out:
# <style  type="text/css" >
# #T_2f458f28_2789_11ed_8403_90e6ba2ecf06row4_col3{
#             background-color:  yellow;
#         }</style><table id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goodbye</th>        <th class="col_heading level0 col1" >greeting</th>        <th class="col_heading level0 col2" >hello_goodbye</th>        <th class="col_heading level0 col3" >manager</th>    </tr>    <tr>        <th class="index_name level0" >dlg_id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row0_col2" class="data row0 col2" >True</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row0_col3" class="data row0 col3" >Ангелина</td>
#             </tr>
#             <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row1_col2" class="data row1 col2" >True</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row1_col3" class="data row1 col3" >Ангелина</td>
#             </tr>
#             <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row2_col2" class="data row2 col2" >False</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row2_col3" class="data row2 col3" >Ангелина</td>
#             </tr>
#             <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row3_col2" class="data row3 col2" >True</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row3_col3" class="data row3 col3" >Максим</td>
#             </tr>
#             <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row4_col2" class="data row4 col2" >False</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row4_col3" class="data row4 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row5_col0" class="data row5 col0" >1</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row5_col2" class="data row5 col2" >False</td>
#                         <td id="T_2f458f28_2789_11ed_8403_90e6ba2ecf06row5_col3" class="data row5 col3" >Анастасия</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Результат

# %% [markdown]
# Получили таблицу c промаркированными True/False строками в которых менеджер поздоровался, представился, попрощался, а также извлеченными именами и названиями компании.

# %%
data[data['dlg_id']==1].head(5)
# Out:
#      dlg_id  line_n     role  \
# 109       1       0   client
# 110       1       1  manager
# 111       1       2  manager
# 112       1       3  manager
# 113       1       4  manager
#
#                                                                                                                                     text  \
# 109                                                                                                  Да здравствуйте когда заканчивается
# 110                                                                                                                    Алло здравствуйте
# 111  Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления а мы сели обратила внимание что у вас срок заканчивается
# 112                                                                                                 А так у вас заканчивается 25 февраля
# 113                                                                                                               На полгода минимальный
#
#      greeting  introduce   manager                   company  goodbye
# 109     False      False      None                      None    False
# 110      True      False      None                      None    False
# 111     False       True  Ангелина  компания диджитал бизнес    False
# 112     False      False      None                      None    False
# 113     False      False      None                      None    False

# %% [markdown]
# Проверка требования "в каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом" выполнена отдельной таблицей.

# %%
hello_goodbye
# Out:
#         goodbye  greeting  hello_goodbye    manager
# dlg_id
# 0             1         1           True   Ангелина
# 1             2         1           True   Ангелина
# 2             0         1          False   Ангелина
# 3             1         1           True     Максим
# 4             1         0          False        NaN
# 5             1         0          False  Анастасия

# %% [markdown]
# Результаты работы сохраняем в файлах csv

# %%
data.to_csv('pars_data.csv', encoding='cp1251')

# %%
hello_goodbye.to_csv('hello_goodbye_data.csv', encoding='cp1251')

# %% [markdown]
# Спасибо за интересную задачу и уделенное внимание.
# В случае вашей заинтересованности с радостью рассмотрю варианты трудоустройства.
# Волонцевич Олег
# +7 (915) 254-31-96 тел. / WhatsApp / Telegram
